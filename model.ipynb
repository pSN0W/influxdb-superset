# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("src/datatraining.txt")

# %%
df.columns
# Out:
# Index(['date', 'Temperature', 'Humidity', 'Light', 'CO2', 'HumidityRatio',
#        'Occupancy'],
#       dtype='object')

# %%
labels = df["Occupancy"].values

# %%
features = df[["Temperature", "Humidity", "Light", "CO2", "HumidityRatio"]].values

# %%
scaler = StandardScaler()
scaler.fit(features)
X = scaler.transform(features)

# %%
linear_model = LogisticRegression().fit(X,labels)

# %%
import joblib

# %%
# joblib.dump(scaler, "./src/models/scaler.joblib")
joblib.dump(clf, "models/tree_model.joblib")
# Out:
# ['models/tree_model.joblib']

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/sn0w/Desktop/IIITA/Sem7/bda/Project/test.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/home/sn0w/Desktop/IIITA/Sem7/bda/Project/test.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> import matplotlib.pyplot as plt
#       <a href='vscode-notebook-cell:/home/sn0w/Desktop/IIITA/Sem7/bda/Project/test.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> from sklearn.datasets import load_iris
#       <a href='vscode-notebook-cell:/home/sn0w/Desktop/IIITA/Sem7/bda/Project/test.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> from sklearn.tree import DecisionTreeClassifier, plot_tree
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
clf = DecisionTreeClassifier(max_depth=4)

# %%
from sklearn.datasets import load_iris

# %%
clf.fit(features,labels)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
plt.figure(figsize=(15, 10))
plot_tree(
    clf,
    filled=True,
    feature_names=["Temperature", "Humidity", "Light", "CO2", "HumidityRatio"],
    class_names=["Occupancy","No Occupancy"],
    rounded=True,
    impurity=False
)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier, plot_tree

# Load the iris dataset for demonstration
iris = load_iris()
X = iris.data
y = iris.target

# Initialize the decision tree classifier
tree_classifier = DecisionTreeClassifier(random_state=42)

# Fit the decision tree on the data
tree_classifier.fit(X, y)

# Plot the decision tree
plt.figure(figsize=(15, 10))
plot_tree(
    tree_classifier,
    filled=True,
    feature_names=iris.feature_names,
    class_names=iris.target_names,
    rounded=True,
)
plt.show()

# %%
import joblib

# %%
model = joblib.load('./models/tree_model.joblib')

# %%
joblib.dump()
